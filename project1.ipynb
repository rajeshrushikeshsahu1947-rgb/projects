# %%
# !pip install icrawler
# Out:
# ...
#    ---------------------------------------- 0.0/4.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.5/4.0 MB 3.4 MB/s eta 0:00:02
#    ------- -------------------------------- 0.8/4.0 MB 2.6 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/4.0 MB 1.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 1.0/4.0 MB 1.8 MB/s eta 0:00:02
#    ------------ --------------------------- 1.3/4.0 MB 1.2 MB/s eta 0:00:03
#    ------------------ --------------------- 1.8/4.0 MB 1.4 MB/s eta 0:00:02
#    -------------------- ------------------- 2.1/4.0 MB 1.5 MB/s eta 0:00:02
#    ----------------------- ---------------- 2.4/4.0 MB 1.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 2.4/4.0 MB 1.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 2.4/4.0 MB 1.3 MB/s eta 0:00:02
#    ----------------------- ---------------- 2.4/4.0 MB 1.3 MB/s eta 0:00:02
# ...

# %%
# !pip install labelImg
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#    ---------------------------------------- 0.0/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/6.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.5/6.9 MB 390.1 kB/s eta 0:00:17
#    ---- ----------------------------------- 0.8/6.9 MB 621.2 kB/s eta 0:00:10
#    ------- -------------------------------- 1.3/6.9 MB 958.5 kB/s eta 0:00:06
#    ------- -------------------------------- 1.3/6.9 MB 958.5 kB/s eta 0:00:06
# ...

# %%
from icrawler.builtin import BingImageCrawler

crawler = BingImageCrawler(
    storage={'root_dir': 'dataset/building_workers'}
)

crawler.crawl(
    keyword='construction workers',
    max_num=100
)
# Out:
# 2026-01-20 20:09:45,724 - INFO - icrawler.crawler - start crawling...
# 2026-01-20 20:09:45,725 - INFO - icrawler.crawler - starting 1 feeder threads...
# 2026-01-20 20:09:45,727 - INFO - feeder - thread feeder-001 exit
# 2026-01-20 20:09:45,737 - INFO - icrawler.crawler - starting 1 parser threads...
# 2026-01-20 20:09:45,741 - INFO - icrawler.crawler - starting 1 downloader threads...
# 2026-01-20 20:09:47,418 - INFO - parser - parsing result page https://www.bing.com/images/async?q=construction workers&first=0
# 2026-01-20 20:09:49,958 - INFO - downloader - image #1	https://static1.bigstockphoto.com/5/0/8/large1500/80552069.jpg
# 2026-01-20 20:09:51,409 - INFO - downloader - image #2	https://wallpaperaccess.com/full/8432871.jpg
# 2026-01-20 20:09:52,886 - INFO - downloader - image #3	https://c8.alamy.com/comp/E8GNF6/happy-construction-workers-at-construction-site-E8GNF6.jpg
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Rajesh\\projects'
